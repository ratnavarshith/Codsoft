# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('/content/creditcard.csv', error_bad_lines=False)
# Out:
# <ipython-input-2-9e591ae76f62>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv('/content/creditcard.csv', error_bad_lines=False)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15936 entries, 0 to 15935
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    15936 non-null  int64
#  1   V1      15936 non-null  float64
#  2   V2      15936 non-null  float64
#  3   V3      15936 non-null  float64
#  4   V4      15936 non-null  float64
#  5   V5      15936 non-null  float64
#  6   V6      15936 non-null  float64
#  7   V7      15936 non-null  float64
#  8   V8      15936 non-null  float64
#  9   V9      15936 non-null  float64
#  10  V10     15936 non-null  float64
#  11  V11     15936 non-null  float64
#  12  V12     15936 non-null  float64
#  13  V13     15936 non-null  float64
#  14  V14     15936 non-null  float64
#  15  V15     15936 non-null  float64
#  16  V16     15936 non-null  float64
#  17  V17     15936 non-null  float64
#  18  V18     15936 non-null  float64
#  19  V19     15936 non-null  float64
# ...

# %%
data.shape
# Out:
# (15935, 31)

# %%
data['Class'].value_counts()
# Out:
# 0.0    15862
# 1.0       73
# Name: Class, dtype: int64

# %%
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
legit.shape
# Out:
# (15862, 31)

# %%
fraud.shape
# Out:
# (73, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  15935.000000  15935.000000  15935.000000  15935.000000  15935.000000
# mean   12120.260872     -0.254396      0.277226      0.803938      0.301421
# std     8981.753206      1.843095      1.491528      1.704271      1.491727
# min        0.000000    -28.344757    -40.978852    -27.368650     -5.172595
# 25%     3633.000000     -0.970838     -0.286415      0.371882     -0.620946
# 50%    10980.000000     -0.318487      0.247479      0.941842      0.231458
# 75%    20617.000000      1.161927      0.884715      1.576016      1.180129
# max    27370.000000      1.960497     14.601998      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  15935.000000  15935.000000  15935.000000  15935.000000  15935.000000
# mean      -0.130464      0.112588     -0.150437      0.000702      0.860951
# ...

# %%
legit.Amount.describe()
# Out:
# count    15862.000000
# mean        66.280151
# std        188.898885
# min          0.000000
# 25%          5.522500
# 50%         15.950000
# 75%         53.890000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      73.000000
# mean       90.307123
# std       271.634360
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1       V2         V3        V4        V5  \
# Class
# 0.0    12104.432165 -0.219072  0.25000   0.862854  0.272641 -0.105868
# 1.0    15559.643836 -7.929807  6.19312 -11.997831  6.555050 -5.474984
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.124522 -0.112681 -0.016178  0.879120  ...  0.028173 -0.064056
# 1.0   -2.480356 -8.354317  3.668478 -3.086988  ...  0.671905  0.441100
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.161585 -0.035040  0.013076  0.117023  0.037111  0.011206  0.005907
# 1.0   -0.295856 -0.358994 -0.328925  0.216076  0.209323  0.927187  0.061380
#
#           Amount
# Class
# 0.0    66.280151
# 1.0    90.307123
#
# [2 rows x 30 columns]

# %% [markdown]
#   UNDERSAMPLING

# %%
legit_sample = legit.sample(n=73)

# %%
new_ds = pd.concat([legit_sample,fraud],axis=0)

# %%
new_ds['Time']==37474
# Out:
# 4797     False
# 10625    False
# 6926     False
# 11615    False
# 8866     False
#          ...
# 15566    False
# 15736    False
# 15751    False
# 15781    False
# 15810    False
# Name: Time, Length: 146, dtype: bool

# %%
new_ds.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 4797    4276 -2.536796 -1.093282  2.826740  1.117317  0.705051 -0.266838
# 10625  17823  0.207373 -1.954527  0.596477  0.531017 -1.306705  0.724606
# 6926    8978 -0.750219  1.522132  1.379289  0.664853  0.204471 -0.313285
# 11615  19912  1.416081 -0.620775  0.291178 -0.543213 -0.720621 -0.021452
# 8866   12141 -2.520594  1.472805  0.616720 -0.927833 -0.704913 -0.902595
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 4797  -0.099354 -0.084594  1.033094  ... -0.130864  0.196939 -0.085057
# 10625 -0.375980  0.188867  2.203370  ...  0.077247 -0.493900 -0.374127
# 6926   0.466306 -0.069341  0.911815  ... -0.363999 -0.600960  0.033850
# 11615 -0.880390  0.044849  0.891189  ... -0.195373 -0.328531 -0.113600
# 8866   0.273930  0.275107  2.591406  ... -0.398975 -0.131186  0.094493
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_ds.tail()
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 15566  26961 -23.237920  13.487386 -25.188773  6.261733 -17.345188 -4.534989
# 15736  27163 -23.914101  13.765942 -25.733734  6.290918 -17.784824 -4.572498
# 15751  27187 -24.590245  14.044567 -26.278701  6.320089 -18.224513 -4.609968
# 15781  27219 -25.266355  14.323254 -26.823673  6.349248 -18.664251 -4.647403
# 15810  27252 -25.942434  14.601998 -27.368650  6.378395 -19.104033 -4.684806
#
#               V7         V8        V9  ...       V21       V22       V23  \
# 15566 -17.100492  15.374630 -3.845567  ...  1.769708 -1.691973 -1.045673
# 15736 -17.390764  15.794136 -3.819832  ...  1.773399 -1.748426 -1.093104
# 15751 -17.681003  16.213627 -3.794093  ...  1.777063 -1.804874 -1.140605
# 15781 -17.971212  16.633103 -3.768351  ...  1.780701 -1.861318 -1.188167
# 15810 -18.261393  17.052566 -3.742605  ...  1.784316 -1.917759 -1.235787
#
# ...

# %%
new_ds.shape
# Out:
# (146, 31)

# %%
new_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 4797 to 15810
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    146 non-null    int64
#  1   V1      146 non-null    float64
#  2   V2      146 non-null    float64
#  3   V3      146 non-null    float64
#  4   V4      146 non-null    float64
#  5   V5      146 non-null    float64
#  6   V6      146 non-null    float64
#  7   V7      146 non-null    float64
#  8   V8      146 non-null    float64
#  9   V9      146 non-null    float64
#  10  V10     146 non-null    float64
#  11  V11     146 non-null    float64
#  12  V12     146 non-null    float64
#  13  V13     146 non-null    float64
#  14  V14     146 non-null    float64
#  15  V15     146 non-null    float64
#  16  V16     146 non-null    float64
#  17  V17     146 non-null    float64
#  18  V18     146 non-null    float64
#  19  V19     146 non-null    float64
# ...

# %%
new_ds['Class'].value_counts()
# Out:
# 0.0    73
# 1.0    73
# Name: Class, dtype: int64

# %%
new_ds['Class'] = new_ds['Class'].astype(int)

# %%
new_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 4797 to 15810
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    146 non-null    int64
#  1   V1      146 non-null    float64
#  2   V2      146 non-null    float64
#  3   V3      146 non-null    float64
#  4   V4      146 non-null    float64
#  5   V5      146 non-null    float64
#  6   V6      146 non-null    float64
#  7   V7      146 non-null    float64
#  8   V8      146 non-null    float64
#  9   V9      146 non-null    float64
#  10  V10     146 non-null    float64
#  11  V11     146 non-null    float64
#  12  V12     146 non-null    float64
#  13  V13     146 non-null    float64
#  14  V14     146 non-null    float64
#  15  V15     146 non-null    float64
#  16  V16     146 non-null    float64
#  17  V17     146 non-null    float64
#  18  V18     146 non-null    float64
#  19  V19     146 non-null    float64
# ...

# %%
new_ds.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 4797    4276 -2.536796 -1.093282  2.826740  1.117317  0.705051 -0.266838
# 10625  17823  0.207373 -1.954527  0.596477  0.531017 -1.306705  0.724606
# 6926    8978 -0.750219  1.522132  1.379289  0.664853  0.204471 -0.313285
# 11615  19912  1.416081 -0.620775  0.291178 -0.543213 -0.720621 -0.021452
# 8866   12141 -2.520594  1.472805  0.616720 -0.927833 -0.704913 -0.902595
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 4797  -0.099354 -0.084594  1.033094  ... -0.130864  0.196939 -0.085057
# 10625 -0.375980  0.188867  2.203370  ...  0.077247 -0.493900 -0.374127
# 6926   0.466306 -0.069341  0.911815  ... -0.363999 -0.600960  0.033850
# 11615 -0.880390  0.044849  0.891189  ... -0.195373 -0.328531 -0.113600
# 8866   0.273930  0.275107  2.591406  ... -0.398975 -0.131186  0.094493
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
X = new_ds.drop(columns='Class',axis=1)
Y = new_ds['Class']

# %%
print(X)
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 4797    4276  -2.536796  -1.093282   2.826740  1.117317   0.705051 -0.266838
# 10625  17823   0.207373  -1.954527   0.596477  0.531017  -1.306705  0.724606
# 6926    8978  -0.750219   1.522132   1.379289  0.664853   0.204471 -0.313285
# 11615  19912   1.416081  -0.620775   0.291178 -0.543213  -0.720621 -0.021452
# 8866   12141  -2.520594   1.472805   0.616720 -0.927833  -0.704913 -0.902595
# ...      ...        ...        ...        ...       ...        ...       ...
# 15566  26961 -23.237920  13.487386 -25.188773  6.261733 -17.345188 -4.534989
# 15736  27163 -23.914101  13.765942 -25.733734  6.290918 -17.784824 -4.572498
# 15751  27187 -24.590245  14.044567 -26.278701  6.320089 -18.224513 -4.609968
# 15781  27219 -25.266355  14.323254 -26.823673  6.349248 -18.664251 -4.647403
# 15810  27252 -25.942434  14.601998 -27.368650  6.378395 -19.104033 -4.684806
#
# ...

# %%
print(Y)
# Out:
# 4797     0
# 10625    0
# 6926     0
# 11615    0
# 8866     0
#         ..
# 15566    1
# 15736    1
# 15751    1
# 15781    1
# 15810    1
# Name: Class, Length: 146, dtype: int64

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (146, 30) (116, 30) (30, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction  = model.predict(X_train)
train_accuracy = accuracy_score(X_train_prediction,Y_train)
print('Accuracy for training data is ',train_accuracy *100)
# Out:
# Accuracy for training data is  98.27586206896551

# %%
X_test_prediction  = model.predict(X_test)
test_accuracy = accuracy_score(X_test_prediction,Y_test)
print('Accuracy for testing data is ',test_accuracy *100)
# Out:
# Accuracy for testing data is  90.0

# %%
input = [1.2744969151658,-0.0161040787432057,0.896236005019314,1.16582189057421,-0.650514327947233,-0.0397864491357658,-0.345682088266809,0.303258857960948,0.203829913019113,0.188933355715981,1.40498656132702,0.070322830355816,-1.93573895900971,0.790810203367295,0.910932327193436,0.392029636811267,-0.374188267503392,0.107531246974214,-0.60419758503422,-0.253400693316875,-0.0623013276558235,-0.303880573467037,0.147353830738904,0.14143791801049,0.10275840887019,-0.558281005210936,0.0386430859938909,0.0224971384606406,18,0]

in_np = np.asarray(input)
np_reshape = in_np.reshape(1,-1)
prediction  = model.predict(np_reshape)
print(prediction)
# Out:
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if(prediction == 0):
  print('It is a Normal Transaction')
else:
  print('It is a fraudent Transaction')
# Out:
# It is a Normal Transaction
